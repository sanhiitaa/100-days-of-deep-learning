# %% [markdown]
# <a href="https://colab.research.google.com/github/sanhiitaa/100-days-of-deep-learning/blob/main/guided-projects/next_word_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pre-processing textual data

# %% [markdown]
# I asked chatgpt to generate 100 sentences for this task and used the same.

# %%
text='''The cat sat on the mat.
The sun is shining brightly today.
She sells seashells by the seashore.
The quick brown fox jumps over the lazy dog.
The rain in Spain stays mainly in the plain.
Mary had a little lamb whose fleece was white as snow.
Jack and Jill went up the hill to fetch a pail of water.
Humpty Dumpty sat on a wall, Humpty Dumpty had a great fall.
It was the best of times, it was the worst of times.
A journey of a thousand miles begins with a single step.
To be or not to be, that is the question.
All that glitters is not gold.
The early bird catches the worm.
A picture is worth a thousand words.
Actions speak louder than words.
An apple a day keeps the doctor away.
Better late than never.
Birds of a feather flock together.
Don't count your chickens before they hatch.
Every cloud has a silver lining.
A friend in need is a friend indeed.
Haste makes waste.
Honesty is the best policy.
If it ain't broke, don't fix it.
Ignorance is bliss.
Knowledge is power.
Laughter is the best medicine.
Look before you leap.
Money doesn't grow on trees.
Necessity is the mother of invention.
No pain, no gain.
Once bitten, twice shy.
One good turn deserves another.
Out of sight, out of mind.
Practice makes perfect.
Rome wasn't built in a day.
The pen is mightier than the sword.
Time heals all wounds.
Too many cooks spoil the broth.
Two heads are better than one.
Where there's a will, there's a way.
You can lead a horse to water, but you can't make it drink.
You can't judge a book by its cover.
Beauty is in the eye of the beholder.
Beggars can't be choosers.
Curiosity killed the cat.
Don't bite the hand that feeds you.
Don't put all your eggs in one basket.
Good things come to those who wait.
If you want something done right, do it yourself.
The only limit to our realization of tomorrow is our doubts of today.
Life is what happens when you're busy making other plans.
The future belongs to those who believe in the beauty of their dreams.
The best way to predict the future is to create it.
Do not watch the clock; do what it does. Keep going.
Keep your face always toward the sunshine—and shadows will fall behind you.
The only impossible journey is the one you never begin.
In the end, we will remember not the words of our enemies, but the silence of our friends.
Life is 10% what happens to us and 90% how we react to it.
It does not matter how slowly you go as long as you do not stop.
Your time is limited, so don’t waste it living someone else’s life.
If life were predictable it would cease to be life, and be without flavor.
In the middle of every difficulty lies opportunity.
To love and be loved is to feel the sun from both sides.
The best and most beautiful things in the world cannot be seen or even touched—they must be felt with the heart.
Life is either a daring adventure or nothing at all.
The only way to do great work is to love what you do.
You miss 100% of the shots you don’t take.
Change your thoughts and you change your world.
I can’t change the direction of the wind, but I can adjust my sails to always reach my destination.
Believe you can and you're halfway there.
The only thing we have to fear is fear itself.
Don’t judge each day by the harvest you reap but by the seeds that you plant.
The journey of a thousand miles begins with one step.
It's not whether you get knocked down, it's whether you get up.
The only person you are destined to become is the person you decide to be.
I have not failed. I've just found 10,000 ways that won't work.
It is never too late to be what you might have been.
What lies behind us and what lies before us are tiny matters compared to what lies within us.
The mind is everything. What you think you become.
Happiness is not something ready made. It comes from your own actions.
The purpose of our lives is to be happy.
Life is really simple, but we insist on making it complicated.
Life is short, and it is up to you to make it sweet.
You only live once, but if you do it right, once is enough.
Good friends, good books, and a sleepy conscience: this is the ideal life.
Life is made of ever so many partings welded together.
Live in the sunshine, swim the sea, drink the wild air.
Don't cry because it's over, smile because it happened.
To live is the rarest thing in the world. Most people exist, that is all.
To be yourself in a world that is constantly trying to make you something else is the greatest accomplishment.
The unexamined life is not worth living.
In three words I can sum up everything I've learned about life: it goes on.
Life is about making an impact, not making an income.
The best way to find yourself is to lose yourself in the service of others.
You must be the change you wish to see in the world.
The greatest glory in living lies not in never falling, but in rising every time we fall.
Do not go where the path may lead, go instead where there is no path and leave a trail.
Life isn’t about waiting for the storm to pass, it’s about learning to dance in the rain.
Success is not final, failure is not fatal: It is the courage to continue that counts.'''

text1=

# %% [markdown]
# ## Importing Libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import numpy as np

# %% [markdown]
# ## Tokenizing our text

# %%
token= Tokenizer()

# %%
token.fit_on_texts([text])

# %%
token.word_index
# Out:
# {'the': 1,
#  'is': 2,
#  'to': 3,
#  'you': 4,
#  'a': 5,
#  'of': 6,
#  'it': 7,
#  'in': 8,
#  'not': 9,
#  'life': 10,
#  'be': 11,
#  'and': 12,
#  'what': 13,
#  'that': 14,
#  'do': 15,
#  'your': 16,
#  'but': 17,
#  'best': 18,
#  'only': 19,
#  'on': 20,
#  'all': 21,
#  "don't": 22,
#  'one': 23,
#  'our': 24,
#  'we': 25,
#  'lies': 26,
#  'world': 27,
#  'by': 28,
#  'up': 29,
#  'words': 30,
#  'than': 31,
#  'never': 32,
#  'if': 33,
#  'good': 34,
#  'way': 35,
#  'can': 36,
#  'yourself': 37,
#  'making': 38,
#  'us': 39,
#  'change': 40,
#  'i': 41,
#  'about': 42,
#  'was': 43,
#  'as': 44,
#  'fall': 45,
#  'journey': 46,
#  'thousand': 47,
#  'with': 48,
#  'or': 49,
#  'an': 50,
#  'day': 51,
#  'before': 52,
#  'every': 53,
#  'no': 54,
#  'once': 55,
#  'time': 56,
#  'are': 57,
#  'where': 58,
#  'will': 59,
#  "can't": 60,
#  'make': 61,
#  'something': 62,
#  'go': 63,
#  'don’t': 64,
#  'living': 65,
#  'have': 66,
#  "it's": 67,
#  'live': 68,
#  'cat': 69,
#  'sat': 70,
#  'sun': 71,
#  'today': 72,
#  'over': 73,
#  'rain': 74,
#  'had': 75,
#  'water': 76,
#  'humpty': 77,
#  'dumpty': 78,
#  'great': 79,
#  'times': 80,
#  'miles': 81,
#  'begins': 82,
#  'step': 83,
#  'worth': 84,
#  'actions': 85,
#  'better': 86,
#  'late': 87,
#  'together': 88,
#  'friend': 89,
#  'makes': 90,
#  'waste': 91,
#  'out': 92,
#  'mind': 93,
#  'too': 94,
#  'many': 95,
#  "there's": 96,
#  'lead': 97,
#  'drink': 98,
#  'judge': 99,
#  'beauty': 100,
#  'things': 101,
#  'those': 102,
#  'who': 103,
#  'right': 104,
#  'happens': 105,
#  "you're": 106,
#  'future': 107,
#  'believe': 108,
#  'does': 109,
#  'keep': 110,
#  'always': 111,
#  'behind': 112,
#  'friends': 113,
#  '10': 114,
#  'how': 115,
#  'so': 116,
#  'love': 117,
#  'from': 118,
#  'most': 119,
#  'must': 120,
#  'work': 121,
#  'my': 122,
#  'there': 123,
#  'thing': 124,
#  'fear': 125,
#  'whether': 126,
#  'get': 127,
#  'person': 128,
#  'become': 129,
#  "i've": 130,
#  'everything': 131,
#  'made': 132,
#  'because': 133,
#  'greatest': 134,
#  'path': 135,
#  'mat': 136,
#  'shining': 137,
#  'brightly': 138,
#  'she': 139,
#  'sells': 140,
#  'seashells': 141,
#  'seashore': 142,
#  'quick': 143,
#  'brown': 144,
#  'fox': 145,
#  'jumps': 146,
#  'lazy': 147,
#  'dog': 148,
#  'spain': 149,
#  'stays': 150,
#  'mainly': 151,
#  'plain': 152,
#  'mary': 153,
#  'little': 154,
#  'lamb': 155,
#  'whose': 156,
#  'fleece': 157,
#  'white': 158,
#  'snow': 159,
#  'jack': 160,
#  'jill': 161,
#  'went': 162,
#  'hill': 163,
#  'fetch': 164,
#  'pail': 165,
#  'wall': 166,
#  'worst': 167,
#  'single': 168,
#  'question': 169,
#  'glitters': 170,
#  'gold': 171,
#  'early': 172,
#  'bird': 173,
#  'catches': 174,
#  'worm': 175,
#  'picture': 176,
#  'speak': 177,
#  'louder': 178,
#  'apple': 179,
#  'keeps': 180,
#  'doctor': 181,
#  'away': 182,
#  'birds': 183,
#  'feather': 184,
#  'flock': 185,
#  'count': 186,
#  'chickens': 187,
#  'they': 188,
#  'hatch': 189,
#  'cloud': 190,
#  'has': 191,
#  'silver': 192,
#  'lining': 193,
#  'need': 194,
#  'indeed': 195,
#  'haste': 196,
#  'honesty': 197,
#  'policy': 198,
#  "ain't": 199,
#  'broke': 200,
#  'fix': 201,
#  'ignorance': 202,
#  'bliss': 203,
#  'knowledge': 204,
#  'power': 205,
#  'laughter': 206,
#  'medicine': 207,
#  'look': 208,
#  'leap': 209,
#  'money': 210,
#  "doesn't": 211,
#  'grow': 212,
#  'trees': 213,
#  'necessity': 214,
#  'mother': 215,
#  'invention': 216,
#  'pain': 217,
#  'gain': 218,
#  'bitten': 219,
#  'twice': 220,
#  'shy': 221,
#  'turn': 222,
#  'deserves': 223,
#  'another': 224,
#  'sight': 225,
#  'practice': 226,
#  'perfect': 227,
#  'rome': 228,
#  "wasn't": 229,
#  'built': 230,
#  'pen': 231,
#  'mightier': 232,
#  'sword': 233,
#  'heals': 234,
#  'wounds': 235,
#  'cooks': 236,
#  'spoil': 237,
#  'broth': 238,
#  'two': 239,
#  'heads': 240,
#  'horse': 241,
#  'book': 242,
#  'its': 243,
#  'cover': 244,
#  'eye': 245,
#  'beholder': 246,
#  'beggars': 247,
#  'choosers': 248,
#  'curiosity': 249,
#  'killed': 250,
#  'bite': 251,
#  'hand': 252,
#  'feeds': 253,
#  'put': 254,
#  'eggs': 255,
#  'basket': 256,
#  'come': 257,
#  'wait': 258,
#  'want': 259,
#  'done': 260,
#  'limit': 261,
#  'realization': 262,
#  'tomorrow': 263,
#  'doubts': 264,
#  'when': 265,
#  'busy': 266,
#  'other': 267,
#  'plans': 268,
#  'belongs': 269,
#  'their': 270,
#  'dreams': 271,
#  'predict': 272,
#  'create': 273,
#  'watch': 274,
#  'clock': 275,
#  'going': 276,
#  'face': 277,
#  'toward': 278,
#  'sunshine—and': 279,
#  'shadows': 280,
#  'impossible': 281,
#  'begin': 282,
#  'end': 283,
#  'remember': 284,
#  'enemies': 285,
#  'silence': 286,
#  '90': 287,
#  'react': 288,
#  'matter': 289,
#  'slowly': 290,
#  'long': 291,
#  'stop': 292,
#  'limited': 293,
#  'someone': 294,
#  'else’s': 295,
#  'were': 296,
#  'predictable': 297,
#  'would': 298,
#  'cease': 299,
#  'without': 300,
#  'flavor': 301,
#  'middle': 302,
#  'difficulty': 303,
#  'opportunity': 304,
#  'loved': 305,
#  'feel': 306,
#  'both': 307,
#  'sides': 308,
#  'beautiful': 309,
#  'cannot': 310,
#  'seen': 311,
#  'even': 312,
#  'touched—they': 313,
#  'felt': 314,
#  'heart': 315,
#  'either': 316,
#  'daring': 317,
#  'adventure': 318,
#  'nothing': 319,
#  'at': 320,
#  'miss': 321,
#  '100': 322,
#  'shots': 323,
#  'take': 324,
#  'thoughts': 325,
#  'can’t': 326,
#  'direction': 327,
#  'wind': 328,
#  'adjust': 329,
#  'sails': 330,
#  'reach': 331,
#  'destination': 332,
#  'halfway': 333,
#  'itself': 334,
#  'each': 335,
#  'harvest': 336,
#  'reap': 337,
#  'seeds': 338,
#  'plant': 339,
#  'knocked': 340,
#  'down': 341,
#  'destined': 342,
#  'decide': 343,
#  'failed': 344,
#  'just': 345,
#  'found': 346,
#  '000': 347,
#  'ways': 348,
#  "won't": 349,
#  'might': 350,
#  'been': 351,
#  'tiny': 352,
#  'matters': 353,
#  'compared': 354,
#  'within': 355,
#  'think': 356,
#  'happiness': 357,
#  'ready': 358,
#  'comes': 359,
#  'own': 360,
#  'purpose': 361,
#  'lives': 362,
#  'happy': 363,
#  'really': 364,
#  'simple': 365,
#  'insist': 366,
#  'complicated': 367,
#  'short': 368,
#  'sweet': 369,
#  'enough': 370,
#  'books': 371,
#  'sleepy': 372,
#  'conscience': 373,
#  'this': 374,
#  'ideal': 375,
#  'ever': 376,
#  'partings': 377,
#  'welded': 378,
#  'sunshine': 379,
#  'swim': 380,
#  'sea': 381,
#  'wild': 382,
#  'air': 383,
#  'cry': 384,
#  'smile': 385,
#  'happened': 386,
#  'rarest': 387,
#  'people': 388,
#  'exist': 389,
#  'constantly': 390,
#  'trying': 391,
#  'else': 392,
#  'accomplishment': 393,
#  'unexamined': 394,
#  'three': 395,
#  'sum': 396,
#  'learned': 397,
#  'goes': 398,
#  'impact': 399,
#  'income': 400,
#  'find': 401,
#  'lose': 402,
#  'service': 403,
#  'others': 404,
#  'wish': 405,
#  'see': 406,
#  'glory': 407,
#  'falling': 408,
#  'rising': 409,
#  'may': 410,
#  'instead': 411,
#  'leave': 412,
#  'trail': 413,
#  'isn’t': 414,
#  'waiting': 415,
#  'for': 416,
#  'storm': 417,
#  'pass': 418,
#  'it’s': 419,
#  'learning': 420,
#  'dance': 421,
#  'success': 422,
#  'final': 423,
#  'failure': 424,
#  'fatal': 425,
#  'courage': 426,
#  'continue': 427,
#  'counts': 428}

# %%
len(token.word_index)
# Out:
# 428

# %%
for sentence in text.split('\n'):
  print(sentence)
# Out:
# The cat sat on the mat.
# The sun is shining brightly today.
# She sells seashells by the seashore.
# The quick brown fox jumps over the lazy dog.
# The rain in Spain stays mainly in the plain.
# Mary had a little lamb whose fleece was white as snow.
# Jack and Jill went up the hill to fetch a pail of water.
# Humpty Dumpty sat on a wall, Humpty Dumpty had a great fall.
# It was the best of times, it was the worst of times.
# A journey of a thousand miles begins with a single step.
# To be or not to be, that is the question.
# All that glitters is not gold.
# The early bird catches the worm.
# A picture is worth a thousand words.
# Actions speak louder than words.
# An apple a day keeps the doctor away.
# Better late than never.
# Birds of a feather flock together.
# Don't count your chickens before they hatch.
# Every cloud has a silver lining.
# A friend in need is a friend indeed.
# Haste makes waste.
# Honesty is the best policy.
# If it ain't broke, don't fix it.
# Ignorance is bliss.
# Knowledge is power.
# Laughter is the best medicine.
# Look before you leap.
# Money doesn't grow on trees.
# Necessity is the mother of invention.
# No pain, no gain.
# Once bitten, twice shy.
# One good turn deserves another.
# Out of sight, out of mind.
# Practice makes perfect.
# Rome wasn't built in a day.
# The pen is mightier than the sword.
# Time heals all wounds.
# Too many cooks spoil the broth.
# Two heads are better than one.
# Where there's a will, there's a way.
# You can lead a horse to water, but you can't make it drink.
# You can't judge a book by its cover.
# Beauty is in the eye of the beholder.
# Beggars can't be choosers.
# Curiosity killed the cat.
# Don't bite the hand that feeds you.
# Don't put all your eggs in one basket.
# Good things come to those who wait.
# If you want something done right, do it yourself.
# The only limit to our realization of tomorrow is our doubts of today.
# Life is what happens when you're busy making other plans.
# The future belongs to those who believe in the beauty of their dreams.
# The best way to predict the future is to create it.
# Do not watch the clock; do what it does. Keep going.
# Keep your face always toward the sunshine—and shadows will fall behind you.
# The only impossible journey is the one you never begin.
# In the end, we will remember not the words of our enemies, but the silence of our friends.
# Life is 10% what happens to us and 90% how we react to it.
# It does not matter how slowly you go as long as you do not stop.
# Your time is limited, so don’t waste it living someone else’s life.
# If life were predictable it would cease to be life, and be without flavor.
# In the middle of every difficulty lies opportunity.
# To love and be loved is to feel the sun from both sides.
# The best and most beautiful things in the world cannot be seen or even touched—they must be felt with the heart.
# Life is either a daring adventure or nothing at all.
# The only way to do great work is to love what you do.
# You miss 100% of the shots you don’t take.
# Change your thoughts and you change your world.
# I can’t change the direction of the wind, but I can adjust my sails to always reach my destination.
# Believe you can and you're halfway there.
# The only thing we have to fear is fear itself.
# Don’t judge each day by the harvest you reap but by the seeds that you plant.
# The journey of a thousand miles begins with one step.
# It's not whether you get knocked down, it's whether you get up.
# The only person you are destined to become is the person you decide to be.
# I have not failed. I've just found 10,000 ways that won't work.
# It is never too late to be what you might have been.
# What lies behind us and what lies before us are tiny matters compared to what lies within us.
# The mind is everything. What you think you become.
# Happiness is not something ready made. It comes from your own actions.
# The purpose of our lives is to be happy.
# Life is really simple, but we insist on making it complicated.
# Life is short, and it is up to you to make it sweet.
# You only live once, but if you do it right, once is enough.
# Good friends, good books, and a sleepy conscience: this is the ideal life.
# Life is made of ever so many partings welded together.
# Live in the sunshine, swim the sea, drink the wild air.
# Don't cry because it's over, smile because it happened.
# To live is the rarest thing in the world. Most people exist, that is all.
# To be yourself in a world that is constantly trying to make you something else is the greatest accomplishment.
# The unexamined life is not worth living.
# In three words I can sum up everything I've learned about life: it goes on.
# Life is about making an impact, not making an income.
# The best way to find yourself is to lose yourself in the service of others.
# You must be the change you wish to see in the world.
# The greatest glory in living lies not in never falling, but in rising every time we fall.
# Do not go where the path may lead, go instead where there is no path and leave a trail.
# Life isn’t about waiting for the storm to pass, it’s about learning to dance in the rain.
# Success is not final, failure is not fatal: It is the courage to continue that counts.

# %%
input_sequences=[]

for sentence in text.split('\n'):
  tokenized_sentence = token.texts_to_sequences([sentence])[0] # converting sentences to their respective sequences
  print(tokenized_sentence) # for visualization purpose

  #
  for i in range(1, len(tokenized_sentence)):
    n_gram_sequence= tokenized_sentence[:i+1]
    input_sequences.append(n_gram_sequence)
# Out:
# [1, 69, 70, 20, 1, 136]
# [1, 71, 2, 137, 138, 72]
# [139, 140, 141, 28, 1, 142]
# [1, 143, 144, 145, 146, 73, 1, 147, 148]
# [1, 74, 8, 149, 150, 151, 8, 1, 152]
# [153, 75, 5, 154, 155, 156, 157, 43, 158, 44, 159]
# [160, 12, 161, 162, 29, 1, 163, 3, 164, 5, 165, 6, 76]
# [77, 78, 70, 20, 5, 166, 77, 78, 75, 5, 79, 45]
# [7, 43, 1, 18, 6, 80, 7, 43, 1, 167, 6, 80]
# [5, 46, 6, 5, 47, 81, 82, 48, 5, 168, 83]
# [3, 11, 49, 9, 3, 11, 14, 2, 1, 169]
# [21, 14, 170, 2, 9, 171]
# [1, 172, 173, 174, 1, 175]
# [5, 176, 2, 84, 5, 47, 30]
# [85, 177, 178, 31, 30]
# [50, 179, 5, 51, 180, 1, 181, 182]
# [86, 87, 31, 32]
# [183, 6, 5, 184, 185, 88]
# [22, 186, 16, 187, 52, 188, 189]
# [53, 190, 191, 5, 192, 193]
# [5, 89, 8, 194, 2, 5, 89, 195]
# [196, 90, 91]
# [197, 2, 1, 18, 198]
# [33, 7, 199, 200, 22, 201, 7]
# [202, 2, 203]
# [204, 2, 205]
# [206, 2, 1, 18, 207]
# [208, 52, 4, 209]
# [210, 211, 212, 20, 213]
# [214, 2, 1, 215, 6, 216]
# [54, 217, 54, 218]
# [55, 219, 220, 221]
# [23, 34, 222, 223, 224]
# [92, 6, 225, 92, 6, 93]
# [226, 90, 227]
# [228, 229, 230, 8, 5, 51]
# [1, 231, 2, 232, 31, 1, 233]
# [56, 234, 21, 235]
# [94, 95, 236, 237, 1, 238]
# [239, 240, 57, 86, 31, 23]
# [58, 96, 5, 59, 96, 5, 35]
# [4, 36, 97, 5, 241, 3, 76, 17, 4, 60, 61, 7, 98]
# [4, 60, 99, 5, 242, 28, 243, 244]
# [100, 2, 8, 1, 245, 6, 1, 246]
# [247, 60, 11, 248]
# [249, 250, 1, 69]
# [22, 251, 1, 252, 14, 253, 4]
# [22, 254, 21, 16, 255, 8, 23, 256]
# [34, 101, 257, 3, 102, 103, 258]
# [33, 4, 259, 62, 260, 104, 15, 7, 37]
# [1, 19, 261, 3, 24, 262, 6, 263, 2, 24, 264, 6, 72]
# [10, 2, 13, 105, 265, 106, 266, 38, 267, 268]
# [1, 107, 269, 3, 102, 103, 108, 8, 1, 100, 6, 270, 271]
# [1, 18, 35, 3, 272, 1, 107, 2, 3, 273, 7]
# [15, 9, 274, 1, 275, 15, 13, 7, 109, 110, 276]
# [110, 16, 277, 111, 278, 1, 279, 280, 59, 45, 112, 4]
# [1, 19, 281, 46, 2, 1, 23, 4, 32, 282]
# [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285, 17, 1, 286, 6, 24, 113]
# [10, 2, 114, 13, 105, 3, 39, 12, 287, 115, 25, 288, 3, 7]
# [7, 109, 9, 289, 115, 290, 4, 63, 44, 291, 44, 4, 15, 9, 292]
# [16, 56, 2, 293, 116, 64, 91, 7, 65, 294, 295, 10]
# [33, 10, 296, 297, 7, 298, 299, 3, 11, 10, 12, 11, 300, 301]
# [8, 1, 302, 6, 53, 303, 26, 304]
# [3, 117, 12, 11, 305, 2, 3, 306, 1, 71, 118, 307, 308]
# [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11, 311, 49, 312, 313, 120, 11, 314, 48, 1, 315]
# [10, 2, 316, 5, 317, 318, 49, 319, 320, 21]
# [1, 19, 35, 3, 15, 79, 121, 2, 3, 117, 13, 4, 15]
# [4, 321, 322, 6, 1, 323, 4, 64, 324]
# [40, 16, 325, 12, 4, 40, 16, 27]
# [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329, 122, 330, 3, 111, 331, 122, 332]
# [108, 4, 36, 12, 106, 333, 123]
# [1, 19, 124, 25, 66, 3, 125, 2, 125, 334]
# [64, 99, 335, 51, 28, 1, 336, 4, 337, 17, 28, 1, 338, 14, 4, 339]
# [1, 46, 6, 5, 47, 81, 82, 48, 23, 83]
# [67, 9, 126, 4, 127, 340, 341, 67, 126, 4, 127, 29]
# [1, 19, 128, 4, 57, 342, 3, 129, 2, 1, 128, 4, 343, 3, 11]
# [41, 66, 9, 344, 130, 345, 346, 114, 347, 348, 14, 349, 121]
# [7, 2, 32, 94, 87, 3, 11, 13, 4, 350, 66, 351]
# [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353, 354, 3, 13, 26, 355, 39]
# [1, 93, 2, 131, 13, 4, 356, 4, 129]
# [357, 2, 9, 62, 358, 132, 7, 359, 118, 16, 360, 85]
# [1, 361, 6, 24, 362, 2, 3, 11, 363]
# [10, 2, 364, 365, 17, 25, 366, 20, 38, 7, 367]
# [10, 2, 368, 12, 7, 2, 29, 3, 4, 3, 61, 7, 369]
# [4, 19, 68, 55, 17, 33, 4, 15, 7, 104, 55, 2, 370]
# [34, 113, 34, 371, 12, 5, 372, 373, 374, 2, 1, 375, 10]
# [10, 2, 132, 6, 376, 116, 95, 377, 378, 88]
# [68, 8, 1, 379, 380, 1, 381, 98, 1, 382, 383]
# [22, 384, 133, 67, 73, 385, 133, 7, 386]
# [3, 68, 2, 1, 387, 124, 8, 1, 27, 119, 388, 389, 14, 2, 21]
# [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4, 62, 392, 2, 1, 134, 393]
# [1, 394, 10, 2, 9, 84, 65]
# [8, 395, 30, 41, 36, 396, 29, 131, 130, 397, 42, 10, 7, 398, 20]
# [10, 2, 42, 38, 50, 399, 9, 38, 50, 400]
# [1, 18, 35, 3, 401, 37, 2, 3, 402, 37, 8, 1, 403, 6, 404]
# [4, 120, 11, 1, 40, 4, 405, 3, 406, 8, 1, 27]
# [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17, 8, 409, 53, 56, 25, 45]
# [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123, 2, 54, 135, 12, 412, 5, 413]
# [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42, 420, 3, 421, 8, 1, 74]
# [422, 2, 9, 423, 424, 2, 9, 425, 7, 2, 1, 426, 3, 427, 14, 428]

# %%
print('total input sequences after creating n_gram sequences: ', len(input_sequences), '\n\n**********************************')
print('n_gram sequences: \n')
input_sequences
# Out:
# total input sequences after creating n_gram sequences:  874
#
# **********************************
# n_gram sequences:
# [[1, 69],
#  [1, 69, 70],
#  [1, 69, 70, 20],
#  [1, 69, 70, 20, 1],
#  [1, 69, 70, 20, 1, 136],
#  [1, 71],
#  [1, 71, 2],
#  [1, 71, 2, 137],
#  [1, 71, 2, 137, 138],
#  [1, 71, 2, 137, 138, 72],
#  [139, 140],
#  [139, 140, 141],
#  [139, 140, 141, 28],
#  [139, 140, 141, 28, 1],
#  [139, 140, 141, 28, 1, 142],
#  [1, 143],
#  [1, 143, 144],
#  [1, 143, 144, 145],
#  [1, 143, 144, 145, 146],
#  [1, 143, 144, 145, 146, 73],
#  [1, 143, 144, 145, 146, 73, 1],
#  [1, 143, 144, 145, 146, 73, 1, 147],
#  [1, 143, 144, 145, 146, 73, 1, 147, 148],
#  [1, 74],
#  [1, 74, 8],
#  [1, 74, 8, 149],
#  [1, 74, 8, 149, 150],
#  [1, 74, 8, 149, 150, 151],
#  [1, 74, 8, 149, 150, 151, 8],
#  [1, 74, 8, 149, 150, 151, 8, 1],
#  [1, 74, 8, 149, 150, 151, 8, 1, 152],
#  [153, 75],
#  [153, 75, 5],
#  [153, 75, 5, 154],
#  [153, 75, 5, 154, 155],
#  [153, 75, 5, 154, 155, 156],
#  [153, 75, 5, 154, 155, 156, 157],
#  [153, 75, 5, 154, 155, 156, 157, 43],
#  [153, 75, 5, 154, 155, 156, 157, 43, 158],
#  [153, 75, 5, 154, 155, 156, 157, 43, 158, 44],
#  [153, 75, 5, 154, 155, 156, 157, 43, 158, 44, 159],
#  [160, 12],
#  [160, 12, 161],
#  [160, 12, 161, 162],
#  [160, 12, 161, 162, 29],
#  [160, 12, 161, 162, 29, 1],
#  [160, 12, 161, 162, 29, 1, 163],
#  [160, 12, 161, 162, 29, 1, 163, 3],
#  [160, 12, 161, 162, 29, 1, 163, 3, 164],
#  [160, 12, 161, 162, 29, 1, 163, 3, 164, 5],
#  [160, 12, 161, 162, 29, 1, 163, 3, 164, 5, 165],
#  [160, 12, 161, 162, 29, 1, 163, 3, 164, 5, 165, 6],
#  [160, 12, 161, 162, 29, 1, 163, 3, 164, 5, 165, 6, 76],
#  [77, 78],
#  [77, 78, 70],
#  [77, 78, 70, 20],
#  [77, 78, 70, 20, 5],
#  [77, 78, 70, 20, 5, 166],
#  [77, 78, 70, 20, 5, 166, 77],
#  [77, 78, 70, 20, 5, 166, 77, 78],
#  [77, 78, 70, 20, 5, 166, 77, 78, 75],
#  [77, 78, 70, 20, 5, 166, 77, 78, 75, 5],
#  [77, 78, 70, 20, 5, 166, 77, 78, 75, 5, 79],
#  [77, 78, 70, 20, 5, 166, 77, 78, 75, 5, 79, 45],
#  [7, 43],
#  [7, 43, 1],
#  [7, 43, 1, 18],
#  [7, 43, 1, 18, 6],
#  [7, 43, 1, 18, 6, 80],
#  [7, 43, 1, 18, 6, 80, 7],
#  [7, 43, 1, 18, 6, 80, 7, 43],
#  [7, 43, 1, 18, 6, 80, 7, 43, 1],
#  [7, 43, 1, 18, 6, 80, 7, 43, 1, 167],
#  [7, 43, 1, 18, 6, 80, 7, 43, 1, 167, 6],
#  [7, 43, 1, 18, 6, 80, 7, 43, 1, 167, 6, 80],
#  [5, 46],
#  [5, 46, 6],
#  [5, 46, 6, 5],
#  [5, 46, 6, 5, 47],
#  [5, 46, 6, 5, 47, 81],
#  [5, 46, 6, 5, 47, 81, 82],
#  [5, 46, 6, 5, 47, 81, 82, 48],
#  [5, 46, 6, 5, 47, 81, 82, 48, 5],
#  [5, 46, 6, 5, 47, 81, 82, 48, 5, 168],
#  [5, 46, 6, 5, 47, 81, 82, 48, 5, 168, 83],
#  [3, 11],
#  [3, 11, 49],
#  [3, 11, 49, 9],
#  [3, 11, 49, 9, 3],
#  [3, 11, 49, 9, 3, 11],
#  [3, 11, 49, 9, 3, 11, 14],
#  [3, 11, 49, 9, 3, 11, 14, 2],
#  [3, 11, 49, 9, 3, 11, 14, 2, 1],
#  [3, 11, 49, 9, 3, 11, 14, 2, 1, 169],
#  [21, 14],
#  [21, 14, 170],
#  [21, 14, 170, 2],
#  [21, 14, 170, 2, 9],
#  [21, 14, 170, 2, 9, 171],
#  [1, 172],
#  [1, 172, 173],
#  [1, 172, 173, 174],
#  [1, 172, 173, 174, 1],
#  [1, 172, 173, 174, 1, 175],
#  [5, 176],
#  [5, 176, 2],
#  [5, 176, 2, 84],
#  [5, 176, 2, 84, 5],
#  [5, 176, 2, 84, 5, 47],
#  [5, 176, 2, 84, 5, 47, 30],
#  [85, 177],
#  [85, 177, 178],
#  [85, 177, 178, 31],
#  [85, 177, 178, 31, 30],
#  [50, 179],
#  [50, 179, 5],
#  [50, 179, 5, 51],
#  [50, 179, 5, 51, 180],
#  [50, 179, 5, 51, 180, 1],
#  [50, 179, 5, 51, 180, 1, 181],
#  [50, 179, 5, 51, 180, 1, 181, 182],
#  [86, 87],
#  [86, 87, 31],
#  [86, 87, 31, 32],
#  [183, 6],
#  [183, 6, 5],
#  [183, 6, 5, 184],
#  [183, 6, 5, 184, 185],
#  [183, 6, 5, 184, 185, 88],
#  [22, 186],
#  [22, 186, 16],
#  [22, 186, 16, 187],
#  [22, 186, 16, 187, 52],
#  [22, 186, 16, 187, 52, 188],
#  [22, 186, 16, 187, 52, 188, 189],
#  [53, 190],
#  [53, 190, 191],
#  [53, 190, 191, 5],
#  [53, 190, 191, 5, 192],
#  [53, 190, 191, 5, 192, 193],
#  [5, 89],
#  [5, 89, 8],
#  [5, 89, 8, 194],
#  [5, 89, 8, 194, 2],
#  [5, 89, 8, 194, 2, 5],
#  [5, 89, 8, 194, 2, 5, 89],
#  [5, 89, 8, 194, 2, 5, 89, 195],
#  [196, 90],
#  [196, 90, 91],
#  [197, 2],
#  [197, 2, 1],
#  [197, 2, 1, 18],
#  [197, 2, 1, 18, 198],
#  [33, 7],
#  [33, 7, 199],
#  [33, 7, 199, 200],
#  [33, 7, 199, 200, 22],
#  [33, 7, 199, 200, 22, 201],
#  [33, 7, 199, 200, 22, 201, 7],
#  [202, 2],
#  [202, 2, 203],
#  [204, 2],
#  [204, 2, 205],
#  [206, 2],
#  [206, 2, 1],
#  [206, 2, 1, 18],
#  [206, 2, 1, 18, 207],
#  [208, 52],
#  [208, 52, 4],
#  [208, 52, 4, 209],
#  [210, 211],
#  [210, 211, 212],
#  [210, 211, 212, 20],
#  [210, 211, 212, 20, 213],
#  [214, 2],
#  [214, 2, 1],
#  [214, 2, 1, 215],
#  [214, 2, 1, 215, 6],
#  [214, 2, 1, 215, 6, 216],
#  [54, 217],
#  [54, 217, 54],
#  [54, 217, 54, 218],
#  [55, 219],
#  [55, 219, 220],
#  [55, 219, 220, 221],
#  [23, 34],
#  [23, 34, 222],
#  [23, 34, 222, 223],
#  [23, 34, 222, 223, 224],
#  [92, 6],
#  [92, 6, 225],
#  [92, 6, 225, 92],
#  [92, 6, 225, 92, 6],
#  [92, 6, 225, 92, 6, 93],
#  [226, 90],
#  [226, 90, 227],
#  [228, 229],
#  [228, 229, 230],
#  [228, 229, 230, 8],
#  [228, 229, 230, 8, 5],
#  [228, 229, 230, 8, 5, 51],
#  [1, 231],
#  [1, 231, 2],
#  [1, 231, 2, 232],
#  [1, 231, 2, 232, 31],
#  [1, 231, 2, 232, 31, 1],
#  [1, 231, 2, 232, 31, 1, 233],
#  [56, 234],
#  [56, 234, 21],
#  [56, 234, 21, 235],
#  [94, 95],
#  [94, 95, 236],
#  [94, 95, 236, 237],
#  [94, 95, 236, 237, 1],
#  [94, 95, 236, 237, 1, 238],
#  [239, 240],
#  [239, 240, 57],
#  [239, 240, 57, 86],
#  [239, 240, 57, 86, 31],
#  [239, 240, 57, 86, 31, 23],
#  [58, 96],
#  [58, 96, 5],
#  [58, 96, 5, 59],
#  [58, 96, 5, 59, 96],
#  [58, 96, 5, 59, 96, 5],
#  [58, 96, 5, 59, 96, 5, 35],
#  [4, 36],
#  [4, 36, 97],
#  [4, 36, 97, 5],
#  [4, 36, 97, 5, 241],
#  [4, 36, 97, 5, 241, 3],
#  [4, 36, 97, 5, 241, 3, 76],
#  [4, 36, 97, 5, 241, 3, 76, 17],
#  [4, 36, 97, 5, 241, 3, 76, 17, 4],
#  [4, 36, 97, 5, 241, 3, 76, 17, 4, 60],
#  [4, 36, 97, 5, 241, 3, 76, 17, 4, 60, 61],
#  [4, 36, 97, 5, 241, 3, 76, 17, 4, 60, 61, 7],
#  [4, 36, 97, 5, 241, 3, 76, 17, 4, 60, 61, 7, 98],
#  [4, 60],
#  [4, 60, 99],
#  [4, 60, 99, 5],
#  [4, 60, 99, 5, 242],
#  [4, 60, 99, 5, 242, 28],
#  [4, 60, 99, 5, 242, 28, 243],
#  [4, 60, 99, 5, 242, 28, 243, 244],
#  [100, 2],
#  [100, 2, 8],
#  [100, 2, 8, 1],
#  [100, 2, 8, 1, 245],
#  [100, 2, 8, 1, 245, 6],
#  [100, 2, 8, 1, 245, 6, 1],
#  [100, 2, 8, 1, 245, 6, 1, 246],
#  [247, 60],
#  [247, 60, 11],
#  [247, 60, 11, 248],
#  [249, 250],
#  [249, 250, 1],
#  [249, 250, 1, 69],
#  [22, 251],
#  [22, 251, 1],
#  [22, 251, 1, 252],
#  [22, 251, 1, 252, 14],
#  [22, 251, 1, 252, 14, 253],
#  [22, 251, 1, 252, 14, 253, 4],
#  [22, 254],
#  [22, 254, 21],
#  [22, 254, 21, 16],
#  [22, 254, 21, 16, 255],
#  [22, 254, 21, 16, 255, 8],
#  [22, 254, 21, 16, 255, 8, 23],
#  [22, 254, 21, 16, 255, 8, 23, 256],
#  [34, 101],
#  [34, 101, 257],
#  [34, 101, 257, 3],
#  [34, 101, 257, 3, 102],
#  [34, 101, 257, 3, 102, 103],
#  [34, 101, 257, 3, 102, 103, 258],
#  [33, 4],
#  [33, 4, 259],
#  [33, 4, 259, 62],
#  [33, 4, 259, 62, 260],
#  [33, 4, 259, 62, 260, 104],
#  [33, 4, 259, 62, 260, 104, 15],
#  [33, 4, 259, 62, 260, 104, 15, 7],
#  [33, 4, 259, 62, 260, 104, 15, 7, 37],
#  [1, 19],
#  [1, 19, 261],
#  [1, 19, 261, 3],
#  [1, 19, 261, 3, 24],
#  [1, 19, 261, 3, 24, 262],
#  [1, 19, 261, 3, 24, 262, 6],
#  [1, 19, 261, 3, 24, 262, 6, 263],
#  [1, 19, 261, 3, 24, 262, 6, 263, 2],
#  [1, 19, 261, 3, 24, 262, 6, 263, 2, 24],
#  [1, 19, 261, 3, 24, 262, 6, 263, 2, 24, 264],
#  [1, 19, 261, 3, 24, 262, 6, 263, 2, 24, 264, 6],
#  [1, 19, 261, 3, 24, 262, 6, 263, 2, 24, 264, 6, 72],
#  [10, 2],
#  [10, 2, 13],
#  [10, 2, 13, 105],
#  [10, 2, 13, 105, 265],
#  [10, 2, 13, 105, 265, 106],
#  [10, 2, 13, 105, 265, 106, 266],
#  [10, 2, 13, 105, 265, 106, 266, 38],
#  [10, 2, 13, 105, 265, 106, 266, 38, 267],
#  [10, 2, 13, 105, 265, 106, 266, 38, 267, 268],
#  [1, 107],
#  [1, 107, 269],
#  [1, 107, 269, 3],
#  [1, 107, 269, 3, 102],
#  [1, 107, 269, 3, 102, 103],
#  [1, 107, 269, 3, 102, 103, 108],
#  [1, 107, 269, 3, 102, 103, 108, 8],
#  [1, 107, 269, 3, 102, 103, 108, 8, 1],
#  [1, 107, 269, 3, 102, 103, 108, 8, 1, 100],
#  [1, 107, 269, 3, 102, 103, 108, 8, 1, 100, 6],
#  [1, 107, 269, 3, 102, 103, 108, 8, 1, 100, 6, 270],
#  [1, 107, 269, 3, 102, 103, 108, 8, 1, 100, 6, 270, 271],
#  [1, 18],
#  [1, 18, 35],
#  [1, 18, 35, 3],
#  [1, 18, 35, 3, 272],
#  [1, 18, 35, 3, 272, 1],
#  [1, 18, 35, 3, 272, 1, 107],
#  [1, 18, 35, 3, 272, 1, 107, 2],
#  [1, 18, 35, 3, 272, 1, 107, 2, 3],
#  [1, 18, 35, 3, 272, 1, 107, 2, 3, 273],
#  [1, 18, 35, 3, 272, 1, 107, 2, 3, 273, 7],
#  [15, 9],
#  [15, 9, 274],
#  [15, 9, 274, 1],
#  [15, 9, 274, 1, 275],
#  [15, 9, 274, 1, 275, 15],
#  [15, 9, 274, 1, 275, 15, 13],
#  [15, 9, 274, 1, 275, 15, 13, 7],
#  [15, 9, 274, 1, 275, 15, 13, 7, 109],
#  [15, 9, 274, 1, 275, 15, 13, 7, 109, 110],
#  [15, 9, 274, 1, 275, 15, 13, 7, 109, 110, 276],
#  [110, 16],
#  [110, 16, 277],
#  [110, 16, 277, 111],
#  [110, 16, 277, 111, 278],
#  [110, 16, 277, 111, 278, 1],
#  [110, 16, 277, 111, 278, 1, 279],
#  [110, 16, 277, 111, 278, 1, 279, 280],
#  [110, 16, 277, 111, 278, 1, 279, 280, 59],
#  [110, 16, 277, 111, 278, 1, 279, 280, 59, 45],
#  [110, 16, 277, 111, 278, 1, 279, 280, 59, 45, 112],
#  [110, 16, 277, 111, 278, 1, 279, 280, 59, 45, 112, 4],
#  [1, 19],
#  [1, 19, 281],
#  [1, 19, 281, 46],
#  [1, 19, 281, 46, 2],
#  [1, 19, 281, 46, 2, 1],
#  [1, 19, 281, 46, 2, 1, 23],
#  [1, 19, 281, 46, 2, 1, 23, 4],
#  [1, 19, 281, 46, 2, 1, 23, 4, 32],
#  [1, 19, 281, 46, 2, 1, 23, 4, 32, 282],
#  [8, 1],
#  [8, 1, 283],
#  [8, 1, 283, 25],
#  [8, 1, 283, 25, 59],
#  [8, 1, 283, 25, 59, 284],
#  [8, 1, 283, 25, 59, 284, 9],
#  [8, 1, 283, 25, 59, 284, 9, 1],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285, 17],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285, 17, 1],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285, 17, 1, 286],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285, 17, 1, 286, 6],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285, 17, 1, 286, 6, 24],
#  [8, 1, 283, 25, 59, 284, 9, 1, 30, 6, 24, 285, 17, 1, 286, 6, 24, 113],
#  [10, 2],
#  [10, 2, 114],
#  [10, 2, 114, 13],
#  [10, 2, 114, 13, 105],
#  [10, 2, 114, 13, 105, 3],
#  [10, 2, 114, 13, 105, 3, 39],
#  [10, 2, 114, 13, 105, 3, 39, 12],
#  [10, 2, 114, 13, 105, 3, 39, 12, 287],
#  [10, 2, 114, 13, 105, 3, 39, 12, 287, 115],
#  [10, 2, 114, 13, 105, 3, 39, 12, 287, 115, 25],
#  [10, 2, 114, 13, 105, 3, 39, 12, 287, 115, 25, 288],
#  [10, 2, 114, 13, 105, 3, 39, 12, 287, 115, 25, 288, 3],
#  [10, 2, 114, 13, 105, 3, 39, 12, 287, 115, 25, 288, 3, 7],
#  [7, 109],
#  [7, 109, 9],
#  [7, 109, 9, 289],
#  [7, 109, 9, 289, 115],
#  [7, 109, 9, 289, 115, 290],
#  [7, 109, 9, 289, 115, 290, 4],
#  [7, 109, 9, 289, 115, 290, 4, 63],
#  [7, 109, 9, 289, 115, 290, 4, 63, 44],
#  [7, 109, 9, 289, 115, 290, 4, 63, 44, 291],
#  [7, 109, 9, 289, 115, 290, 4, 63, 44, 291, 44],
#  [7, 109, 9, 289, 115, 290, 4, 63, 44, 291, 44, 4],
#  [7, 109, 9, 289, 115, 290, 4, 63, 44, 291, 44, 4, 15],
#  [7, 109, 9, 289, 115, 290, 4, 63, 44, 291, 44, 4, 15, 9],
#  [7, 109, 9, 289, 115, 290, 4, 63, 44, 291, 44, 4, 15, 9, 292],
#  [16, 56],
#  [16, 56, 2],
#  [16, 56, 2, 293],
#  [16, 56, 2, 293, 116],
#  [16, 56, 2, 293, 116, 64],
#  [16, 56, 2, 293, 116, 64, 91],
#  [16, 56, 2, 293, 116, 64, 91, 7],
#  [16, 56, 2, 293, 116, 64, 91, 7, 65],
#  [16, 56, 2, 293, 116, 64, 91, 7, 65, 294],
#  [16, 56, 2, 293, 116, 64, 91, 7, 65, 294, 295],
#  [16, 56, 2, 293, 116, 64, 91, 7, 65, 294, 295, 10],
#  [33, 10],
#  [33, 10, 296],
#  [33, 10, 296, 297],
#  [33, 10, 296, 297, 7],
#  [33, 10, 296, 297, 7, 298],
#  [33, 10, 296, 297, 7, 298, 299],
#  [33, 10, 296, 297, 7, 298, 299, 3],
#  [33, 10, 296, 297, 7, 298, 299, 3, 11],
#  [33, 10, 296, 297, 7, 298, 299, 3, 11, 10],
#  [33, 10, 296, 297, 7, 298, 299, 3, 11, 10, 12],
#  [33, 10, 296, 297, 7, 298, 299, 3, 11, 10, 12, 11],
#  [33, 10, 296, 297, 7, 298, 299, 3, 11, 10, 12, 11, 300],
#  [33, 10, 296, 297, 7, 298, 299, 3, 11, 10, 12, 11, 300, 301],
#  [8, 1],
#  [8, 1, 302],
#  [8, 1, 302, 6],
#  [8, 1, 302, 6, 53],
#  [8, 1, 302, 6, 53, 303],
#  [8, 1, 302, 6, 53, 303, 26],
#  [8, 1, 302, 6, 53, 303, 26, 304],
#  [3, 117],
#  [3, 117, 12],
#  [3, 117, 12, 11],
#  [3, 117, 12, 11, 305],
#  [3, 117, 12, 11, 305, 2],
#  [3, 117, 12, 11, 305, 2, 3],
#  [3, 117, 12, 11, 305, 2, 3, 306],
#  [3, 117, 12, 11, 305, 2, 3, 306, 1],
#  [3, 117, 12, 11, 305, 2, 3, 306, 1, 71],
#  [3, 117, 12, 11, 305, 2, 3, 306, 1, 71, 118],
#  [3, 117, 12, 11, 305, 2, 3, 306, 1, 71, 118, 307],
#  [3, 117, 12, 11, 305, 2, 3, 306, 1, 71, 118, 307, 308],
#  [1, 18],
#  [1, 18, 12],
#  [1, 18, 12, 119],
#  [1, 18, 12, 119, 309],
#  [1, 18, 12, 119, 309, 101],
#  [1, 18, 12, 119, 309, 101, 8],
#  [1, 18, 12, 119, 309, 101, 8, 1],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11, 311],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11, 311, 49],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11, 311, 49, 312],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11, 311, 49, 312, 313],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11, 311, 49, 312, 313, 120],
#  [1, 18, 12, 119, 309, 101, 8, 1, 27, 310, 11, 311, 49, 312, 313, 120, 11],
#  [1,
#   18,
#   12,
#   119,
#   309,
#   101,
#   8,
#   1,
#   27,
#   310,
#   11,
#   311,
#   49,
#   312,
#   313,
#   120,
#   11,
#   314],
#  [1,
#   18,
#   12,
#   119,
#   309,
#   101,
#   8,
#   1,
#   27,
#   310,
#   11,
#   311,
#   49,
#   312,
#   313,
#   120,
#   11,
#   314,
#   48],
#  [1,
#   18,
#   12,
#   119,
#   309,
#   101,
#   8,
#   1,
#   27,
#   310,
#   11,
#   311,
#   49,
#   312,
#   313,
#   120,
#   11,
#   314,
#   48,
#   1],
#  [1,
#   18,
#   12,
#   119,
#   309,
#   101,
#   8,
#   1,
#   27,
#   310,
#   11,
#   311,
#   49,
#   312,
#   313,
#   120,
#   11,
#   314,
#   48,
#   1,
#   315],
#  [10, 2],
#  [10, 2, 316],
#  [10, 2, 316, 5],
#  [10, 2, 316, 5, 317],
#  [10, 2, 316, 5, 317, 318],
#  [10, 2, 316, 5, 317, 318, 49],
#  [10, 2, 316, 5, 317, 318, 49, 319],
#  [10, 2, 316, 5, 317, 318, 49, 319, 320],
#  [10, 2, 316, 5, 317, 318, 49, 319, 320, 21],
#  [1, 19],
#  [1, 19, 35],
#  [1, 19, 35, 3],
#  [1, 19, 35, 3, 15],
#  [1, 19, 35, 3, 15, 79],
#  [1, 19, 35, 3, 15, 79, 121],
#  [1, 19, 35, 3, 15, 79, 121, 2],
#  [1, 19, 35, 3, 15, 79, 121, 2, 3],
#  [1, 19, 35, 3, 15, 79, 121, 2, 3, 117],
#  [1, 19, 35, 3, 15, 79, 121, 2, 3, 117, 13],
#  [1, 19, 35, 3, 15, 79, 121, 2, 3, 117, 13, 4],
#  [1, 19, 35, 3, 15, 79, 121, 2, 3, 117, 13, 4, 15],
#  [4, 321],
#  [4, 321, 322],
#  [4, 321, 322, 6],
#  [4, 321, 322, 6, 1],
#  [4, 321, 322, 6, 1, 323],
#  [4, 321, 322, 6, 1, 323, 4],
#  [4, 321, 322, 6, 1, 323, 4, 64],
#  [4, 321, 322, 6, 1, 323, 4, 64, 324],
#  [40, 16],
#  [40, 16, 325],
#  [40, 16, 325, 12],
#  [40, 16, 325, 12, 4],
#  [40, 16, 325, 12, 4, 40],
#  [40, 16, 325, 12, 4, 40, 16],
#  [40, 16, 325, 12, 4, 40, 16, 27],
#  [41, 326],
#  [41, 326, 40],
#  [41, 326, 40, 1],
#  [41, 326, 40, 1, 327],
#  [41, 326, 40, 1, 327, 6],
#  [41, 326, 40, 1, 327, 6, 1],
#  [41, 326, 40, 1, 327, 6, 1, 328],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329, 122],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329, 122, 330],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329, 122, 330, 3],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329, 122, 330, 3, 111],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329, 122, 330, 3, 111, 331],
#  [41, 326, 40, 1, 327, 6, 1, 328, 17, 41, 36, 329, 122, 330, 3, 111, 331, 122],
#  [41,
#   326,
#   40,
#   1,
#   327,
#   6,
#   1,
#   328,
#   17,
#   41,
#   36,
#   329,
#   122,
#   330,
#   3,
#   111,
#   331,
#   122,
#   332],
#  [108, 4],
#  [108, 4, 36],
#  [108, 4, 36, 12],
#  [108, 4, 36, 12, 106],
#  [108, 4, 36, 12, 106, 333],
#  [108, 4, 36, 12, 106, 333, 123],
#  [1, 19],
#  [1, 19, 124],
#  [1, 19, 124, 25],
#  [1, 19, 124, 25, 66],
#  [1, 19, 124, 25, 66, 3],
#  [1, 19, 124, 25, 66, 3, 125],
#  [1, 19, 124, 25, 66, 3, 125, 2],
#  [1, 19, 124, 25, 66, 3, 125, 2, 125],
#  [1, 19, 124, 25, 66, 3, 125, 2, 125, 334],
#  [64, 99],
#  [64, 99, 335],
#  [64, 99, 335, 51],
#  [64, 99, 335, 51, 28],
#  [64, 99, 335, 51, 28, 1],
#  [64, 99, 335, 51, 28, 1, 336],
#  [64, 99, 335, 51, 28, 1, 336, 4],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337, 17],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337, 17, 28],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337, 17, 28, 1],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337, 17, 28, 1, 338],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337, 17, 28, 1, 338, 14],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337, 17, 28, 1, 338, 14, 4],
#  [64, 99, 335, 51, 28, 1, 336, 4, 337, 17, 28, 1, 338, 14, 4, 339],
#  [1, 46],
#  [1, 46, 6],
#  [1, 46, 6, 5],
#  [1, 46, 6, 5, 47],
#  [1, 46, 6, 5, 47, 81],
#  [1, 46, 6, 5, 47, 81, 82],
#  [1, 46, 6, 5, 47, 81, 82, 48],
#  [1, 46, 6, 5, 47, 81, 82, 48, 23],
#  [1, 46, 6, 5, 47, 81, 82, 48, 23, 83],
#  [67, 9],
#  [67, 9, 126],
#  [67, 9, 126, 4],
#  [67, 9, 126, 4, 127],
#  [67, 9, 126, 4, 127, 340],
#  [67, 9, 126, 4, 127, 340, 341],
#  [67, 9, 126, 4, 127, 340, 341, 67],
#  [67, 9, 126, 4, 127, 340, 341, 67, 126],
#  [67, 9, 126, 4, 127, 340, 341, 67, 126, 4],
#  [67, 9, 126, 4, 127, 340, 341, 67, 126, 4, 127],
#  [67, 9, 126, 4, 127, 340, 341, 67, 126, 4, 127, 29],
#  [1, 19],
#  [1, 19, 128],
#  [1, 19, 128, 4],
#  [1, 19, 128, 4, 57],
#  [1, 19, 128, 4, 57, 342],
#  [1, 19, 128, 4, 57, 342, 3],
#  [1, 19, 128, 4, 57, 342, 3, 129],
#  [1, 19, 128, 4, 57, 342, 3, 129, 2],
#  [1, 19, 128, 4, 57, 342, 3, 129, 2, 1],
#  [1, 19, 128, 4, 57, 342, 3, 129, 2, 1, 128],
#  [1, 19, 128, 4, 57, 342, 3, 129, 2, 1, 128, 4],
#  [1, 19, 128, 4, 57, 342, 3, 129, 2, 1, 128, 4, 343],
#  [1, 19, 128, 4, 57, 342, 3, 129, 2, 1, 128, 4, 343, 3],
#  [1, 19, 128, 4, 57, 342, 3, 129, 2, 1, 128, 4, 343, 3, 11],
#  [41, 66],
#  [41, 66, 9],
#  [41, 66, 9, 344],
#  [41, 66, 9, 344, 130],
#  [41, 66, 9, 344, 130, 345],
#  [41, 66, 9, 344, 130, 345, 346],
#  [41, 66, 9, 344, 130, 345, 346, 114],
#  [41, 66, 9, 344, 130, 345, 346, 114, 347],
#  [41, 66, 9, 344, 130, 345, 346, 114, 347, 348],
#  [41, 66, 9, 344, 130, 345, 346, 114, 347, 348, 14],
#  [41, 66, 9, 344, 130, 345, 346, 114, 347, 348, 14, 349],
#  [41, 66, 9, 344, 130, 345, 346, 114, 347, 348, 14, 349, 121],
#  [7, 2],
#  [7, 2, 32],
#  [7, 2, 32, 94],
#  [7, 2, 32, 94, 87],
#  [7, 2, 32, 94, 87, 3],
#  [7, 2, 32, 94, 87, 3, 11],
#  [7, 2, 32, 94, 87, 3, 11, 13],
#  [7, 2, 32, 94, 87, 3, 11, 13, 4],
#  [7, 2, 32, 94, 87, 3, 11, 13, 4, 350],
#  [7, 2, 32, 94, 87, 3, 11, 13, 4, 350, 66],
#  [7, 2, 32, 94, 87, 3, 11, 13, 4, 350, 66, 351],
#  [13, 26],
#  [13, 26, 112],
#  [13, 26, 112, 39],
#  [13, 26, 112, 39, 12],
#  [13, 26, 112, 39, 12, 13],
#  [13, 26, 112, 39, 12, 13, 26],
#  [13, 26, 112, 39, 12, 13, 26, 52],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353, 354],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353, 354, 3],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353, 354, 3, 13],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353, 354, 3, 13, 26],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353, 354, 3, 13, 26, 355],
#  [13, 26, 112, 39, 12, 13, 26, 52, 39, 57, 352, 353, 354, 3, 13, 26, 355, 39],
#  [1, 93],
#  [1, 93, 2],
#  [1, 93, 2, 131],
#  [1, 93, 2, 131, 13],
#  [1, 93, 2, 131, 13, 4],
#  [1, 93, 2, 131, 13, 4, 356],
#  [1, 93, 2, 131, 13, 4, 356, 4],
#  [1, 93, 2, 131, 13, 4, 356, 4, 129],
#  [357, 2],
#  [357, 2, 9],
#  [357, 2, 9, 62],
#  [357, 2, 9, 62, 358],
#  [357, 2, 9, 62, 358, 132],
#  [357, 2, 9, 62, 358, 132, 7],
#  [357, 2, 9, 62, 358, 132, 7, 359],
#  [357, 2, 9, 62, 358, 132, 7, 359, 118],
#  [357, 2, 9, 62, 358, 132, 7, 359, 118, 16],
#  [357, 2, 9, 62, 358, 132, 7, 359, 118, 16, 360],
#  [357, 2, 9, 62, 358, 132, 7, 359, 118, 16, 360, 85],
#  [1, 361],
#  [1, 361, 6],
#  [1, 361, 6, 24],
#  [1, 361, 6, 24, 362],
#  [1, 361, 6, 24, 362, 2],
#  [1, 361, 6, 24, 362, 2, 3],
#  [1, 361, 6, 24, 362, 2, 3, 11],
#  [1, 361, 6, 24, 362, 2, 3, 11, 363],
#  [10, 2],
#  [10, 2, 364],
#  [10, 2, 364, 365],
#  [10, 2, 364, 365, 17],
#  [10, 2, 364, 365, 17, 25],
#  [10, 2, 364, 365, 17, 25, 366],
#  [10, 2, 364, 365, 17, 25, 366, 20],
#  [10, 2, 364, 365, 17, 25, 366, 20, 38],
#  [10, 2, 364, 365, 17, 25, 366, 20, 38, 7],
#  [10, 2, 364, 365, 17, 25, 366, 20, 38, 7, 367],
#  [10, 2],
#  [10, 2, 368],
#  [10, 2, 368, 12],
#  [10, 2, 368, 12, 7],
#  [10, 2, 368, 12, 7, 2],
#  [10, 2, 368, 12, 7, 2, 29],
#  [10, 2, 368, 12, 7, 2, 29, 3],
#  [10, 2, 368, 12, 7, 2, 29, 3, 4],
#  [10, 2, 368, 12, 7, 2, 29, 3, 4, 3],
#  [10, 2, 368, 12, 7, 2, 29, 3, 4, 3, 61],
#  [10, 2, 368, 12, 7, 2, 29, 3, 4, 3, 61, 7],
#  [10, 2, 368, 12, 7, 2, 29, 3, 4, 3, 61, 7, 369],
#  [4, 19],
#  [4, 19, 68],
#  [4, 19, 68, 55],
#  [4, 19, 68, 55, 17],
#  [4, 19, 68, 55, 17, 33],
#  [4, 19, 68, 55, 17, 33, 4],
#  [4, 19, 68, 55, 17, 33, 4, 15],
#  [4, 19, 68, 55, 17, 33, 4, 15, 7],
#  [4, 19, 68, 55, 17, 33, 4, 15, 7, 104],
#  [4, 19, 68, 55, 17, 33, 4, 15, 7, 104, 55],
#  [4, 19, 68, 55, 17, 33, 4, 15, 7, 104, 55, 2],
#  [4, 19, 68, 55, 17, 33, 4, 15, 7, 104, 55, 2, 370],
#  [34, 113],
#  [34, 113, 34],
#  [34, 113, 34, 371],
#  [34, 113, 34, 371, 12],
#  [34, 113, 34, 371, 12, 5],
#  [34, 113, 34, 371, 12, 5, 372],
#  [34, 113, 34, 371, 12, 5, 372, 373],
#  [34, 113, 34, 371, 12, 5, 372, 373, 374],
#  [34, 113, 34, 371, 12, 5, 372, 373, 374, 2],
#  [34, 113, 34, 371, 12, 5, 372, 373, 374, 2, 1],
#  [34, 113, 34, 371, 12, 5, 372, 373, 374, 2, 1, 375],
#  [34, 113, 34, 371, 12, 5, 372, 373, 374, 2, 1, 375, 10],
#  [10, 2],
#  [10, 2, 132],
#  [10, 2, 132, 6],
#  [10, 2, 132, 6, 376],
#  [10, 2, 132, 6, 376, 116],
#  [10, 2, 132, 6, 376, 116, 95],
#  [10, 2, 132, 6, 376, 116, 95, 377],
#  [10, 2, 132, 6, 376, 116, 95, 377, 378],
#  [10, 2, 132, 6, 376, 116, 95, 377, 378, 88],
#  [68, 8],
#  [68, 8, 1],
#  [68, 8, 1, 379],
#  [68, 8, 1, 379, 380],
#  [68, 8, 1, 379, 380, 1],
#  [68, 8, 1, 379, 380, 1, 381],
#  [68, 8, 1, 379, 380, 1, 381, 98],
#  [68, 8, 1, 379, 380, 1, 381, 98, 1],
#  [68, 8, 1, 379, 380, 1, 381, 98, 1, 382],
#  [68, 8, 1, 379, 380, 1, 381, 98, 1, 382, 383],
#  [22, 384],
#  [22, 384, 133],
#  [22, 384, 133, 67],
#  [22, 384, 133, 67, 73],
#  [22, 384, 133, 67, 73, 385],
#  [22, 384, 133, 67, 73, 385, 133],
#  [22, 384, 133, 67, 73, 385, 133, 7],
#  [22, 384, 133, 67, 73, 385, 133, 7, 386],
#  [3, 68],
#  [3, 68, 2],
#  [3, 68, 2, 1],
#  [3, 68, 2, 1, 387],
#  [3, 68, 2, 1, 387, 124],
#  [3, 68, 2, 1, 387, 124, 8],
#  [3, 68, 2, 1, 387, 124, 8, 1],
#  [3, 68, 2, 1, 387, 124, 8, 1, 27],
#  [3, 68, 2, 1, 387, 124, 8, 1, 27, 119],
#  [3, 68, 2, 1, 387, 124, 8, 1, 27, 119, 388],
#  [3, 68, 2, 1, 387, 124, 8, 1, 27, 119, 388, 389],
#  [3, 68, 2, 1, 387, 124, 8, 1, 27, 119, 388, 389, 14],
#  [3, 68, 2, 1, 387, 124, 8, 1, 27, 119, 388, 389, 14, 2],
#  [3, 68, 2, 1, 387, 124, 8, 1, 27, 119, 388, 389, 14, 2, 21],
#  [3, 11],
#  [3, 11, 37],
#  [3, 11, 37, 8],
#  [3, 11, 37, 8, 5],
#  [3, 11, 37, 8, 5, 27],
#  [3, 11, 37, 8, 5, 27, 14],
#  [3, 11, 37, 8, 5, 27, 14, 2],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4, 62],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4, 62, 392],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4, 62, 392, 2],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4, 62, 392, 2, 1],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4, 62, 392, 2, 1, 134],
#  [3, 11, 37, 8, 5, 27, 14, 2, 390, 391, 3, 61, 4, 62, 392, 2, 1, 134, 393],
#  [1, 394],
#  [1, 394, 10],
#  [1, 394, 10, 2],
#  [1, 394, 10, 2, 9],
#  [1, 394, 10, 2, 9, 84],
#  [1, 394, 10, 2, 9, 84, 65],
#  [8, 395],
#  [8, 395, 30],
#  [8, 395, 30, 41],
#  [8, 395, 30, 41, 36],
#  [8, 395, 30, 41, 36, 396],
#  [8, 395, 30, 41, 36, 396, 29],
#  [8, 395, 30, 41, 36, 396, 29, 131],
#  [8, 395, 30, 41, 36, 396, 29, 131, 130],
#  [8, 395, 30, 41, 36, 396, 29, 131, 130, 397],
#  [8, 395, 30, 41, 36, 396, 29, 131, 130, 397, 42],
#  [8, 395, 30, 41, 36, 396, 29, 131, 130, 397, 42, 10],
#  [8, 395, 30, 41, 36, 396, 29, 131, 130, 397, 42, 10, 7],
#  [8, 395, 30, 41, 36, 396, 29, 131, 130, 397, 42, 10, 7, 398],
#  [8, 395, 30, 41, 36, 396, 29, 131, 130, 397, 42, 10, 7, 398, 20],
#  [10, 2],
#  [10, 2, 42],
#  [10, 2, 42, 38],
#  [10, 2, 42, 38, 50],
#  [10, 2, 42, 38, 50, 399],
#  [10, 2, 42, 38, 50, 399, 9],
#  [10, 2, 42, 38, 50, 399, 9, 38],
#  [10, 2, 42, 38, 50, 399, 9, 38, 50],
#  [10, 2, 42, 38, 50, 399, 9, 38, 50, 400],
#  [1, 18],
#  [1, 18, 35],
#  [1, 18, 35, 3],
#  [1, 18, 35, 3, 401],
#  [1, 18, 35, 3, 401, 37],
#  [1, 18, 35, 3, 401, 37, 2],
#  [1, 18, 35, 3, 401, 37, 2, 3],
#  [1, 18, 35, 3, 401, 37, 2, 3, 402],
#  [1, 18, 35, 3, 401, 37, 2, 3, 402, 37],
#  [1, 18, 35, 3, 401, 37, 2, 3, 402, 37, 8],
#  [1, 18, 35, 3, 401, 37, 2, 3, 402, 37, 8, 1],
#  [1, 18, 35, 3, 401, 37, 2, 3, 402, 37, 8, 1, 403],
#  [1, 18, 35, 3, 401, 37, 2, 3, 402, 37, 8, 1, 403, 6],
#  [1, 18, 35, 3, 401, 37, 2, 3, 402, 37, 8, 1, 403, 6, 404],
#  [4, 120],
#  [4, 120, 11],
#  [4, 120, 11, 1],
#  [4, 120, 11, 1, 40],
#  [4, 120, 11, 1, 40, 4],
#  [4, 120, 11, 1, 40, 4, 405],
#  [4, 120, 11, 1, 40, 4, 405, 3],
#  [4, 120, 11, 1, 40, 4, 405, 3, 406],
#  [4, 120, 11, 1, 40, 4, 405, 3, 406, 8],
#  [4, 120, 11, 1, 40, 4, 405, 3, 406, 8, 1],
#  [4, 120, 11, 1, 40, 4, 405, 3, 406, 8, 1, 27],
#  [1, 134],
#  [1, 134, 407],
#  [1, 134, 407, 8],
#  [1, 134, 407, 8, 65],
#  [1, 134, 407, 8, 65, 26],
#  [1, 134, 407, 8, 65, 26, 9],
#  [1, 134, 407, 8, 65, 26, 9, 8],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17, 8],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17, 8, 409],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17, 8, 409, 53],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17, 8, 409, 53, 56],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17, 8, 409, 53, 56, 25],
#  [1, 134, 407, 8, 65, 26, 9, 8, 32, 408, 17, 8, 409, 53, 56, 25, 45],
#  [15, 9],
#  [15, 9, 63],
#  [15, 9, 63, 58],
#  [15, 9, 63, 58, 1],
#  [15, 9, 63, 58, 1, 135],
#  [15, 9, 63, 58, 1, 135, 410],
#  [15, 9, 63, 58, 1, 135, 410, 97],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123, 2],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123, 2, 54],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123, 2, 54, 135],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123, 2, 54, 135, 12],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123, 2, 54, 135, 12, 412],
#  [15, 9, 63, 58, 1, 135, 410, 97, 63, 411, 58, 123, 2, 54, 135, 12, 412, 5],
#  [15,
#   9,
#   63,
#   58,
#   1,
#   135,
#   410,
#   97,
#   63,
#   411,
#   58,
#   123,
#   2,
#   54,
#   135,
#   12,
#   412,
#   5,
#   413],
#  [10, 414],
#  [10, 414, 42],
#  [10, 414, 42, 415],
#  [10, 414, 42, 415, 416],
#  [10, 414, 42, 415, 416, 1],
#  [10, 414, 42, 415, 416, 1, 417],
#  [10, 414, 42, 415, 416, 1, 417, 3],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42, 420],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42, 420, 3],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42, 420, 3, 421],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42, 420, 3, 421, 8],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42, 420, 3, 421, 8, 1],
#  [10, 414, 42, 415, 416, 1, 417, 3, 418, 419, 42, 420, 3, 421, 8, 1, 74],
#  [422, 2],
#  [422, 2, 9],
#  [422, 2, 9, 423],
#  [422, 2, 9, 423, 424],
#  [422, 2, 9, 423, 424, 2],
#  [422, 2, 9, 423, 424, 2, 9],
#  [422, 2, 9, 423, 424, 2, 9, 425],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7, 2],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7, 2, 1],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7, 2, 1, 426],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7, 2, 1, 426, 3],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7, 2, 1, 426, 3, 427],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7, 2, 1, 426, 3, 427, 14],
#  [422, 2, 9, 423, 424, 2, 9, 425, 7, 2, 1, 426, 3, 427, 14, 428]]

# %% [markdown]
# ## Zero Padding the data

# %%
# finding the length of the longest sequence
maxlen=max([len(x) for x in input_sequences])

# %%
# padding the seuqences based on the longest sentence
padded_sequences = pad_sequences(input_sequences, maxlen=maxlen, padding='pre')

# %%
padded_sequences
# Out:
# array([[  0,   0,   0, ...,   0,   1,  69],
#        [  0,   0,   0, ...,   1,  69,  70],
#        [  0,   0,   0, ...,  69,  70,  20],
#        ...,
#        [  0,   0,   0, ..., 426,   3, 427],
#        [  0,   0,   0, ...,   3, 427,  14],
#        [  0,   0,   0, ..., 427,  14, 428]], dtype=int32)

# %%
len(padded_sequences)
# Out:
# 874

# %% [markdown]
# We will use supervised learning to perfrom the next word prediction, classification task specifically.

# %%
# splitting the data into dependent and independent variables
x= padded_sequences[:, :-1]
y= padded_sequences[:, -1]

# %%
# shapes of the variables
x.shape, y.shape
# Out:
# ((874, 20), (874,))

# %% [markdown]
# 1. `x.shape = (num_samples, maxlen-1)`
# 2. `y.shape = (num_samples, num_classes).`

# %%
num_classes= len(token.word_index) + 1 # +1 because indexing starts from one and OHE starts from 0

# OHE the categorical variables.
y = to_categorical(y, num_classes=num_classes)

# %%
# updated shape of the dependent variable
y.shape
# Out:
# (874, 429)

# %% [markdown]
# # Building LSTM Architecture

# %% [markdown]
# For reference:
# 1. `num_classes` : total number of unique words + 1
# 2. `maxlen` : length of the longest sentence

# %%
# building the model

model = Sequential()
model.add(Embedding(num_classes, 100, input_length=maxlen-1)) # -1 because we exclude the last token, it is the first output of y
model.add(LSTM(150))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 20, 100)           42900
#
#  lstm_4 (LSTM)               (None, 150)               150600
#
#  dense_4 (Dense)             (None, 429)               64779
#
# =================================================================
# Total params: 258279 (1008.90 KB)
# Trainable params: 258279 (1008.90 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compiling the model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# fitting the model
model.fit(x,y, epochs=100)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 3s 34ms/step - loss: 5.9163 - accuracy: 0.0503
# Epoch 2/100
# 28/28 [==============================] - 2s 65ms/step - loss: 5.5147 - accuracy: 0.0469
# Epoch 3/100
# 28/28 [==============================] - 2s 64ms/step - loss: 5.4254 - accuracy: 0.0618
# Epoch 4/100
# 28/28 [==============================] - 1s 34ms/step - loss: 5.3865 - accuracy: 0.0584
# Epoch 5/100
# 28/28 [==============================] - 1s 35ms/step - loss: 5.3449 - accuracy: 0.0789
# Epoch 6/100
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2878 - accuracy: 0.0618
# Epoch 7/100
# 28/28 [==============================] - 1s 35ms/step - loss: 5.2062 - accuracy: 0.0847
# Epoch 8/100
# 28/28 [==============================] - 1s 33ms/step - loss: 5.1053 - accuracy: 0.0801
# Epoch 9/100
# 28/28 [==============================] - 1s 33ms/step - loss: 4.9993 - accuracy: 0.0881
# Epoch 10/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.8674 - accuracy: 0.0950
# Epoch 11/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.7338 - accuracy: 0.1236
# Epoch 12/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.5931 - accuracy: 0.1156
# Epoch 13/100
# 28/28 [==============================] - 1s 34ms/step - loss: 4.4354 - accuracy: 0.1476
# Epoch 14/100
# 28/28 [==============================] - 2s 57ms/step - loss: 4.2914 - accuracy: 0.1739
# Epoch 15/100
# 28/28 [==============================] - 2s 68ms/step - loss: 4.1157 - accuracy: 0.1979
# Epoch 16/100
# 28/28 [==============================] - 1s 36ms/step - loss: 3.9653 - accuracy: 0.2197
# Epoch 17/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.8022 - accuracy: 0.2265
# Epoch 18/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.6455 - accuracy: 0.2483
# Epoch 19/100
# 28/28 [==============================] - 1s 34ms/step - loss: 3.4781 - accuracy: 0.2689
# Epoch 20/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.3287 - accuracy: 0.2918
# Epoch 21/100
# 28/28 [==============================] - 1s 33ms/step - loss: 3.1680 - accuracy: 0.3272
# Epoch 22/100
# 28/28 [==============================] - 1s 35ms/step - loss: 3.0245 - accuracy: 0.3581
# Epoch 23/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.8813 - accuracy: 0.3844
# Epoch 24/100
# 28/28 [==============================] - 1s 34ms/step - loss: 2.7410 - accuracy: 0.4153
# Epoch 25/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.6099 - accuracy: 0.4588
# Epoch 26/100
# 28/28 [==============================] - 1s 46ms/step - loss: 2.4715 - accuracy: 0.4908
# Epoch 27/100
# 28/28 [==============================] - 2s 68ms/step - loss: 2.3384 - accuracy: 0.5309
# Epoch 28/100
# 28/28 [==============================] - 1s 47ms/step - loss: 2.2112 - accuracy: 0.5801
# Epoch 29/100
# 28/28 [==============================] - 1s 33ms/step - loss: 2.0937 - accuracy: 0.6213
# Epoch 30/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.9732 - accuracy: 0.6487
# Epoch 31/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.8618 - accuracy: 0.6934
# Epoch 32/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.7562 - accuracy: 0.7025
# Epoch 33/100
# 28/28 [==============================] - 1s 36ms/step - loss: 1.6512 - accuracy: 0.7391
# Epoch 34/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.5521 - accuracy: 0.7574
# Epoch 35/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.4621 - accuracy: 0.7780
# Epoch 36/100
# 28/28 [==============================] - 1s 35ms/step - loss: 1.3721 - accuracy: 0.7895
# Epoch 37/100
# 28/28 [==============================] - 1s 34ms/step - loss: 1.2942 - accuracy: 0.8032
# Epoch 38/100
# 28/28 [==============================] - 1s 45ms/step - loss: 1.2126 - accuracy: 0.8272
# Epoch 39/100
# 28/28 [==============================] - 2s 83ms/step - loss: 1.1436 - accuracy: 0.8352
# Epoch 40/100
# 28/28 [==============================] - 2s 69ms/step - loss: 1.0745 - accuracy: 0.8558
# Epoch 41/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.0125 - accuracy: 0.8627
# Epoch 42/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.9579 - accuracy: 0.8776
# Epoch 43/100
# 28/28 [==============================] - 2s 64ms/step - loss: 0.9034 - accuracy: 0.8844
# Epoch 44/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.8501 - accuracy: 0.8959
# Epoch 45/100
# 28/28 [==============================] - 2s 53ms/step - loss: 0.8055 - accuracy: 0.8970
# Epoch 46/100
# 28/28 [==============================] - 2s 76ms/step - loss: 0.7630 - accuracy: 0.9062
# Epoch 47/100
# 28/28 [==============================] - 2s 86ms/step - loss: 0.7210 - accuracy: 0.9130
# Epoch 48/100
# 28/28 [==============================] - 2s 66ms/step - loss: 0.6889 - accuracy: 0.9188
# Epoch 49/100
# 28/28 [==============================] - 1s 38ms/step - loss: 0.6533 - accuracy: 0.9130
# Epoch 50/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.6187 - accuracy: 0.9211
# Epoch 51/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.5920 - accuracy: 0.9233
# Epoch 52/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.5629 - accuracy: 0.9291
# Epoch 53/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.5379 - accuracy: 0.9222
# Epoch 54/100
# 28/28 [==============================] - 1s 37ms/step - loss: 0.5173 - accuracy: 0.9245
# Epoch 55/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.4958 - accuracy: 0.9302
# Epoch 56/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.4756 - accuracy: 0.9291
# Epoch 57/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.4581 - accuracy: 0.9291
# Epoch 58/100
# 28/28 [==============================] - 2s 63ms/step - loss: 0.4418 - accuracy: 0.9302
# Epoch 59/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.4249 - accuracy: 0.9336
# Epoch 60/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.4089 - accuracy: 0.9279
# Epoch 61/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.3954 - accuracy: 0.9302
# Epoch 62/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.3861 - accuracy: 0.9279
# Epoch 63/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.3698 - accuracy: 0.9314
# Epoch 64/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.3597 - accuracy: 0.9291
# Epoch 65/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.3475 - accuracy: 0.9291
# Epoch 66/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.3384 - accuracy: 0.9279
# Epoch 67/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.3304 - accuracy: 0.9336
# Epoch 68/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.3196 - accuracy: 0.9371
# Epoch 69/100
# 28/28 [==============================] - 2s 62ms/step - loss: 0.3129 - accuracy: 0.9359
# Epoch 70/100
# 28/28 [==============================] - 2s 69ms/step - loss: 0.3039 - accuracy: 0.9336
# Epoch 71/100
# 28/28 [==============================] - 1s 36ms/step - loss: 0.2984 - accuracy: 0.9359
# Epoch 72/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2914 - accuracy: 0.9416
# Epoch 73/100
# 28/28 [==============================] - 1s 36ms/step - loss: 0.2842 - accuracy: 0.9382
# Epoch 74/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2781 - accuracy: 0.9405
# Epoch 75/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2728 - accuracy: 0.9371
# Epoch 76/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2673 - accuracy: 0.9382
# Epoch 77/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2607 - accuracy: 0.9359
# Epoch 78/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2566 - accuracy: 0.9359
# Epoch 79/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2521 - accuracy: 0.9336
# Epoch 80/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2463 - accuracy: 0.9348
# Epoch 81/100
# 28/28 [==============================] - 2s 61ms/step - loss: 0.2448 - accuracy: 0.9382
# Epoch 82/100
# 28/28 [==============================] - 2s 67ms/step - loss: 0.2400 - accuracy: 0.9359
# Epoch 83/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2358 - accuracy: 0.9371
# Epoch 84/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2337 - accuracy: 0.9371
# Epoch 85/100
# 28/28 [==============================] - 1s 36ms/step - loss: 0.2301 - accuracy: 0.9359
# Epoch 86/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2257 - accuracy: 0.9371
# Epoch 87/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2232 - accuracy: 0.9348
# Epoch 88/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2209 - accuracy: 0.9371
# Epoch 89/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2181 - accuracy: 0.9348
# Epoch 90/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2176 - accuracy: 0.9371
# Epoch 91/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2139 - accuracy: 0.9348
# Epoch 92/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2086 - accuracy: 0.9405
# Epoch 93/100
# 28/28 [==============================] - 2s 60ms/step - loss: 0.2058 - accuracy: 0.9394
# Epoch 94/100
# 28/28 [==============================] - 2s 68ms/step - loss: 0.2046 - accuracy: 0.9371
# Epoch 95/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.2022 - accuracy: 0.9325
# Epoch 96/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2029 - accuracy: 0.9405
# Epoch 97/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.2017 - accuracy: 0.9382
# Epoch 98/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.1975 - accuracy: 0.9382
# Epoch 99/100
# 28/28 [==============================] - 1s 35ms/step - loss: 0.1965 - accuracy: 0.9371
# Epoch 100/100
# 28/28 [==============================] - 1s 34ms/step - loss: 0.1941 - accuracy: 0.9394

# %% [markdown]
# ## Prediction

# %%
# text from training data
text='Believe'

for i in range(7):
  # tokenize
  token_text = token.texts_to_sequences([text])[0]

  # padding
  padded_token_text= pad_sequences([token_text], maxlen=maxlen-1, padding='pre')

  # prediction
  position = np.argmax(model.predict(padded_token_text))

  for word, index in token.word_index.items():
    if index == position:
      text = text + ' ' + word
      print(text)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# Believe you
# 1/1 [==============================] - 0s 41ms/step
# Believe you can
# 1/1 [==============================] - 0s 45ms/step
# Believe you can and
# 1/1 [==============================] - 0s 52ms/step
# Believe you can and you're
# 1/1 [==============================] - 0s 23ms/step
# Believe you can and you're halfway
# 1/1 [==============================] - 0s 23ms/step
# Believe you can and you're halfway there
# 1/1 [==============================] - 0s 23ms/step
# Believe you can and you're halfway there there

# %%
# random text
text='Beautiful'

for i in range(7):
  # tokenize
  token_text = token.texts_to_sequences([text])[0]

  # padding
  padded_token_text= pad_sequences([token_text], maxlen=maxlen-1, padding='pre')

  # predict
  position = np.argmax(model.predict(padded_token_text))

  for word, index in token.word_index.items():
    if index == position:
      text = text + ' ' + word
      print(text)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# Beautiful can't
# 1/1 [==============================] - 0s 32ms/step
# Beautiful can't judge
# 1/1 [==============================] - 0s 33ms/step
# Beautiful can't judge a
# 1/1 [==============================] - 0s 52ms/step
# Beautiful can't judge a book
# 1/1 [==============================] - 0s 35ms/step
# Beautiful can't judge a book by
# 1/1 [==============================] - 0s 38ms/step
# Beautiful can't judge a book by its
# 1/1 [==============================] - 0s 35ms/step
# Beautiful can't judge a book by its cover

# %% [markdown]
# To improve perfromance:
# 1. Provide more data.
# 2. Hyperparameter tuning.
# 3. Advanced architectures
#   - Stacked LSTM
#   - Bidirectional LSTM
#   - Transformers
